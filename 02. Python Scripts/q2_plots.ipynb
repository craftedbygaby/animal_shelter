# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
shelter_colors = {
"primary":"#f55e61", 
"secondary":"#f9a8a9",
"dark":"#2a0a0b",
"cream":"#FFF5F5",
"muted":"#9a6060", 
"accent":"#d94a4d"
}

# %%
df = pd.read_csv("/Users/huss/Downloads/shelter_final.csv.csv")

df
# Out:
#        animal_id      name outcome_type outcome_subtype animal_type  \
# 0        A705049    *Fancy     Transfer         Partner         Cat
# 1        A729515      Oreo     Transfer         Partner         Cat
# 2        A680862       NaN     Transfer         Partner        Bird
# 3        A714876   *Newton     Transfer         Partner         Cat
# 4        A706507       NaN         Died       In Kennel         Cat
# ...          ...       ...          ...             ...         ...
# 173770   A926373      *Owl     Adoption          Foster         Cat
# 173771   A926862  *Lagatha     Adoption             NaN         Dog
# 173772   A917477    Canelo     Adoption             NaN         Dog
# 173773   A621834    Nahtha     Adoption             NaN         Dog
# 173774   A929559       NaN     Transfer         Partner         Cat
#
#        sex_upon_outcome age_upon_outcome                     breed  \
# 0         Spayed Female         2 months    Domestic Shorthair Mix
# ...

# %%
#nan remove and see what you want to do with that
# Drop columns which we wont use 

df = df.drop(columns=["name","sex_upon_outcome","outcome_subtype","monthyear"])
df
# Out:
#        animal_id outcome_type animal_type age_upon_outcome  \
# 0        A705049     Transfer         Cat         2 months
# 1        A729515     Transfer         Cat         12 years
# 2        A680862     Transfer        Bird          2 weeks
# 3        A714876     Transfer         Cat          3 years
# 4        A706507         Died         Cat           5 days
# ...          ...          ...         ...              ...
# 173770   A926373     Adoption         Cat          1 month
# 173771   A926862     Adoption         Dog         2 months
# 173772   A917477     Adoption         Dog           1 year
# 173773   A621834     Adoption         Dog         15 years
# 173774   A929559     Transfer         Cat          1 month
#
#                            breed               color  \
# 0         Domestic Shorthair Mix               Black
# 1         Domestic Shorthair Mix         Black/White
# 2                           Duck        Yellow/Black
# ...

# %%
df2=df.dropna()

df2
# Out:
#        animal_id outcome_type animal_type age_upon_outcome  \
# 0        A705049     Transfer         Cat         2 months
# 1        A729515     Transfer         Cat         12 years
# 2        A680862     Transfer        Bird          2 weeks
# 3        A714876     Transfer         Cat          3 years
# 4        A706507         Died         Cat           5 days
# ...          ...          ...         ...              ...
# 173770   A926373     Adoption         Cat          1 month
# 173771   A926862     Adoption         Dog         2 months
# 173772   A917477     Adoption         Dog           1 year
# 173773   A621834     Adoption         Dog         15 years
# 173774   A929559     Transfer         Cat          1 month
#
#                            breed               color  \
# 0         Domestic Shorthair Mix               Black
# 1         Domestic Shorthair Mix         Black/White
# 2                           Duck        Yellow/Black
# ...

# %%
df2["age_upon_outcome"].isna().sum()
df2["outcome_type"].isna().sum()
df2.reset_index (drop=True, inplace =True)

# %%
display(df2)
# Out:
#        animal_id outcome_type animal_type age_upon_outcome  \
# 0        A705049     Transfer         Cat         2 months
# 1        A729515     Transfer         Cat         12 years
# 2        A680862     Transfer        Bird          2 weeks
# 3        A714876     Transfer         Cat          3 years
# 4        A706507         Died         Cat           5 days
# ...          ...          ...         ...              ...
# 173715   A926373     Adoption         Cat          1 month
# 173716   A926862     Adoption         Dog         2 months
# 173717   A917477     Adoption         Dog           1 year
# 173718   A621834     Adoption         Dog         15 years
# 173719   A929559     Transfer         Cat          1 month
#
#                            breed               color  \
# 0         Domestic Shorthair Mix               Black
# 1         Domestic Shorthair Mix         Black/White
# 2                           Duck        Yellow/Black
# ...

# %%
df2.to_csv("clean_shelter_file", index=False)

# %%
adoption1_df = pd.read_csv("/Users/huss/data-processing/week4/Project/1_adoption_type.csv")

adoption2_df = pd.read_csv("/Users/huss/data-processing/week4/Project/2_adoption_animals_percentage.csv")
adoption2_df

adoption3_df = pd.read_csv("/Users/huss/data-processing/week4/Project/3_total_adoption_all_animals.csv")
adoption3_df
# Out:
#   Cell In[32], line 2
#     adoption1_df = adoption1_df.sort_values(by "total_records")
#                                                ^
# SyntaxError: invalid syntax

# %%
adoption1_df = adoption1_df.sort_values(by="total_records", ascending=False)
print(adoption1_df_2)
# Out:
#     pet_type  total_records  adopted_count  adoption_rate_pct
# 0  Livestock             34             17              50.00
# 1       Bird            876            323              36.87
# 2      Other           8950           1002              11.20
# 3        Cat          69386          35781              51.57
# 4        Dog          94474          47475              50.25

# %%
print(adoption1_df)
# Out:
#     pet_type  total_records  adopted_count  adoption_rate_pct
# 4        Dog          94474          47475              50.25
# 3        Cat          69386          35781              51.57
# 2      Other           8950           1002              11.20
# 1       Bird            876            323              36.87
# 0  Livestock             34             17              50.00

# %%
adoption1_df_percentage = adoption1_df.sort_values(by="adoption_rate_pct", ascending=False)
print(adoption1_df_percentage)

adoption1_percentage = sns.barplot(data=adoption1_df_percentage, x='pet_type', y='adoption_rate_pct', palette=[shelter_colors["secondary"]])

adoption1_percentage.set_title('Total Adoption Percentage')
adoption1_percentage.set_xlabel('Pet Type')
adoption1_percentage.set_ylabel('Adoption Rate')
adoption1_percentage.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

adoption1_percentage.get_figure().savefig('../huss/data-processing/week4/Project/animal_shelter/adoption_percentage', dpi=300, bbox_inches='tight')
# Out:
#     pet_type  total_records  adopted_count  adoption_rate_pct
# 3        Cat          69386          35781              51.57
# 4        Dog          94474          47475              50.25
# 0  Livestock             34             17              50.00
# 1       Bird            876            323              36.87
# 2      Other           8950           1002              11.20
# /var/folders/ng/bkj9rn_n6nq1pb1bjcwzcp500000gn/T/ipykernel_5886/1904657173.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   adoption1_percentage = sns.barplot(data=adoption1_df_percentage, x='pet_type', y='adoption_rate_pct', palette=[shelter_colors["secondary"]])
# /var/folders/ng/bkj9rn_n6nq1pb1bjcwzcp500000gn/T/ipykernel_5886/1904657173.py:4: UserWarning:
# ...

# %%
Adoption_types_1 = sns.barplot(data=adoption1_df, x='pet_type', y='total_records', palette=[shelter_colors["secondary"]])


Adoption_types_1.set_title('Total Adoption All Animals')
Adoption_types_1.set_xlabel('Pet Type')
Adoption_types_1.set_ylabel('All Records')
Adoption_types_1.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

Adoption_types_1.get_figure().savefig('../huss/data-processing/week4/Project/animal_shelter/adoption_all_animals', dpi=300, bbox_inches='tight')
# Out:
# /var/folders/ng/bkj9rn_n6nq1pb1bjcwzcp500000gn/T/ipykernel_5886/2189561412.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   Adoption_types_1 = sns.barplot(data=adoption1_df, x='pet_type', y='total_records', palette=[shelter_colors["secondary"]])
# /var/folders/ng/bkj9rn_n6nq1pb1bjcwzcp500000gn/T/ipykernel_5886/2189561412.py:1: UserWarning:
# The palette list has fewer values (1) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   Adoption_types_1 = sns.barplot(data=adoption1_df, x='pet_type', y='total_records', palette=[shelter_colors["secondary"]])

# %%
print(adoption2_df)

#create a table
# Out:
#    total_animals  total_adopted  adoption_percentage
# 0         173720          84598                 48.7

# %%
# Out:
# /var/folders/ng/bkj9rn_n6nq1pb1bjcwzcp500000gn/T/ipykernel_5886/1891972537.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   Adoption_types_1 = sns.barplot(data=adoption2_df, x='total_animals', y='adoption_percentage', palette=[shelter_colors["secondary"]])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ng/bkj9rn_n6nq1pb1bjcwzcp500000gn/T/ipykernel_5886/1891972537.py in ?()
#       1 Adoption_types_1 = sns.barplot(data=adoption2_df, x='total_animals', y='adoption_percentage', palette=[shelter_colors["secondary"]])
#       2
#       3
# ----> 4 adoption2_df.set_title('Total Adoption All Animals')
#       5 adoption2_df.set_xlabel('Pet Type')
#       6 adoption2_df.set_ylabel('All Records')
# ...

# %%
print(adoption3_df)
# Out:
#     pet_type  adopted_count
# 0  Livestock             17
# 1       Bird            323
# 2      Other           1002
# 3        Cat          35781
# 4        Dog          47475
